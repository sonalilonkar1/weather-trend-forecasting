# %%
# %pip install pandas numpy scikit-learn matplotlib seaborn plotly ipykernel
# Out:
# ...
#   Using cached pandas-3.0.3-cp313-cp313-macosx_10_13_x86_64.whl.metadata (79 kB)
# ...
#   Using cached numpy-2.4.6-cp313-cp313-macosx_14_0_x86_64.whl.metadata (6.6 kB)
# ...
#   Using cached scikit_learn-1.9.0-cp313-cp313-macosx_10_13_x86_64.whl.metadata (11 kB)
# ...
#   Using cached matplotlib-3.11.0-cp313-cp313-macosx_10_13_x86_64.whl.metadata (80 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached plotly-6.8.0-py3-none-any.whl.metadata (9.0 kB)
# ...
#   Using cached scipy-1.17.1-cp313-cp313-macosx_14_0_x86_64.whl.metadata (62 kB)
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached narwhals-2.22.1-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-macosx_10_13_x86_64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.63.0-cp313-cp313-macosx_10_13_x86_64.whl.metadata (118 kB)
# ...

# %%
import sys
print(sys.executable)

import pandas as pd
print(pd.__version__)
# Out:
# /Users/sonalilonkar/Desktop/PMA/.venv/bin/python
# 3.0.3

# %%
import pandas as pd
df = pd.read_csv("/Users/sonalilonkar/Desktop/PMA/weather_trends/data/GlobalWeatherRepository.csv")

print(df.shape)
print(df.head())
print(df.columns.tolist())
print(df.info())
print(df.isnull().sum())
# Out:
# (146760, 41)
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...
